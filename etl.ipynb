# %%
import pandas as pd
import pandas_gbq
import sqlalchemy as db

# %% [markdown]
# Creating a series in Panda

# %%
data = pd.Series([10,20,30,40,50])

# %%
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = {
    'Name' : ['Sneha', 'Ovin', 'Akshay'],
    'Age' : [37,2,35],
    'City' : ['nasik','vancouver','pune']
}

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# Read the SBTi excel file stored at

# %%
# xlsx = pd.ExcelFile("/Users/sneha/sbti-dbt/companies-taking-action.xlsx")
# df = pd.read_excel(xlsx)

sbti_csv= pd.read_csv("companies-taking-action.csv")

# %%
sbti_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7978 entries, 0 to 7977
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Company Name                       7978 non-null   object
#  1   ISIN                               2337 non-null   object
#  2   LEI                                2972 non-null   object
#  3   Near term - Target Status          7977 non-null   object
#  4   Near term - Target Classification  4857 non-null   object
#  5   Near term - Target Year            4815 non-null   object
#  6   Long term - Target Status          735 non-null    object
#  7   Long term - Target Classification  745 non-null    object
#  8   Long term - Target Year            740 non-null    object
#  9   Net-Zero Committed                 7978 non-null   object
#  10  Net-Zero Year                      738 non-null    object
# ...

# %%
sbti_csv.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7973    False
# 7974    False
# 7975    False
# 7976    False
# 7977    False
# Length: 7978, dtype: bool

# %%
sbti_csv.shape
# Out:
# (7978, 21)

# %%
sbti_csv.head()
# Out:
#                                         Company Name ISIN  LEI  \
# 0                                              & Co.  NaN  NaN
# 1  (ACIP) Alexandria Company for Industrial Packages  NaN  NaN
# 2                            10 to 2 Consulting, LLC  NaN  NaN
# 3                          100 Percent Group Limited  NaN  NaN
# 4                               2 Sisters Food Group  NaN  NaN
#
#   Near term - Target Status Near term - Target Classification  \
# 0               Targets Set                             1.5°C
# 1               Targets Set                    Well-below 2°C
# 2               Targets Set                             1.5°C
# 3               Targets Set                             1.5°C
# 4                 Committed                               NaN
#
#   Near term - Target Year Long term - Target Status  \
# 0                    2030                       NaN
# 1                    2030                       NaN
# ...

# %%
sbti_csv.columns
# Out:
# Index(['Company Name', 'ISIN', 'LEI', 'Near term - Target Status',
#        'Near term - Target Classification', 'Near term - Target Year',
#        'Long term - Target Status', 'Long term - Target Classification',
#        'Long term - Target Year', 'Net-Zero Committed', 'Net-Zero Year',
#        'Organization Type', 'BA1.5', 'BA1.5 Date', 'Location', 'Region',
#        'Sector', 'Date', 'Target', 'Target Classification', 'Extension'],
#       dtype='object')

# %%
sbti_csv
# Out:
#                                            Company Name          ISIN  \
# 0                                                 & Co.           NaN
# 1     (ACIP) Alexandria Company for Industrial Packages           NaN
# 2                               10 to 2 Consulting, LLC           NaN
# 3                             100 Percent Group Limited           NaN
# 4                                  2 Sisters Food Group           NaN
# ...                                                 ...           ...
# 7973                              Zweifel Pomy-Chips AG           NaN
# 7974                               ZWORKS SOLUTIONS LLP           NaN
# 7975                            Zyxel Group Corporation           NaN
# 7976                                             Ørsted  DK0060094928
# 7977                          ​MCM Architecture Limited           NaN
#
#                        LEI Near term - Target Status  \
# 0                      NaN               Targets Set
# ...

# %%
engine = db.create_engine('postgresql://vrlurxip:nxksNBacsonK6uOG8aCadvfDkaS9trXE@bubble.db.elephantsql.com/vrlurxip', pool_pre_ping=True)

# %% [markdown]
# The following command will upload the data to database using SQlalchemy
#
# <!-- customers.to_sql("customers", engine, if_exists='replace', index=False) -->

# %%
# Errors out
# sbti_csv.to_sql("companies",engine, if_exists='replace',index=False)

# %%
sbti_csv= sbti_csv.drop(columns=['BA1.5','BA1.5 Date'])

# %%
sbti_csv.columns
# Out:
# Index(['Company Name', 'ISIN', 'LEI', 'Near term - Target Status',
#        'Near term - Target Classification', 'Near term - Target Year',
#        'Long term - Target Status', 'Long term - Target Classification',
#        'Long term - Target Year', 'Net-Zero Committed', 'Net-Zero Year',
#        'Organization Type', 'Location', 'Region', 'Sector', 'Date', 'Target',
#        'Target Classification', 'Extension'],
#       dtype='object')

# %%
sbti_csv
# Out:
#                                            Company Name          ISIN  \
# 0                                                 & Co.           NaN
# 1     (ACIP) Alexandria Company for Industrial Packages           NaN
# 2                               10 to 2 Consulting, LLC           NaN
# 3                             100 Percent Group Limited           NaN
# 4                                  2 Sisters Food Group           NaN
# ...                                                 ...           ...
# 7973                              Zweifel Pomy-Chips AG           NaN
# 7974                               ZWORKS SOLUTIONS LLP           NaN
# 7975                            Zyxel Group Corporation           NaN
# 7976                                             Ørsted  DK0060094928
# 7977                          ​MCM Architecture Limited           NaN
#
#                        LEI Near term - Target Status  \
# 0                      NaN               Targets Set
# ...

# %%
pandas_gbq.to_gbq(sbti_csv,'cogent-sign-416620.sbtidashdata.companiestakingaction','cogent-sign-416620',if_exists='replace')

# %% [markdown]
# The above statement did not copy over all the data due to column names having spaces might have to pass infer schema in pandas_gbq
